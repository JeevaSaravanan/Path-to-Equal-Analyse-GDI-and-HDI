# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('archive-2/FineTech_appData.csv')

# %%
data
# Out:
#          user               first_open  dayofweek       hour  age  \
# 0      235136  2012-12-27 02:14:51.273          3   02:00:00   23
# 1      333588  2012-12-02 01:16:00.905          6   01:00:00   24
# 2      254414  2013-03-19 19:19:09.157          1   19:00:00   23
# 3      234192  2013-07-05 16:08:46.354          4   16:00:00   28
# 4       51549  2013-02-26 18:50:48.661          1   18:00:00   31
# ...       ...                      ...        ...        ...  ...
# 49995  222774  2013-05-09 13:46:17.871          3   13:00:00   32
# 49996  169179  2013-04-09 00:05:17.823          1   00:00:00   35
# 49997  302367  2013-02-20 22:41:51.165          2   22:00:00   39
# 49998  324905  2013-04-28 12:33:04.288          6   12:00:00   27
# 49999   27047  2012-12-14 01:22:44.638          4   01:00:00   25
#
#                                              screen_list  numscreens  \
# 0      idscreen,joinscreen,Cycle,product_review,ScanP...          15
# ...

# %%
cleanData = data = pd.read_csv('archive-2/clean_FineTech_appData.csv')
cleanData
# Out:
#        Unnamed: 0    user  dayofweek  hour  age  numscreens  minigame  \
# 0               0  235136          3     2   23          15         0
# 1               1  333588          6     1   24          13         0
# 2               2  254414          1    19   23           3         0
# 3               3  234192          4    16   28          40         0
# 4               4   51549          1    18   31          32         0
# ...           ...     ...        ...   ...  ...         ...       ...
# 49995       49995  222774          3    13   32          13         0
# 49996       49996  169179          1     0   35           4         0
# 49997       49997  302367          2    22   39          25         0
# 49998       49998  324905          6    12   27          26         0
# 49999       49999   27047          4     1   25          26         0
#
#        used_premium_feature  enrolled  liked  ...  SecurityModal  ResendToken  \
# ...

# %%
topScreen = pd.read_csv('archive-2/top_screens.csv')
topScreen
# Out:
#     Unnamed: 0              top_screens
# 0            0                    Loan2
# 1            1                 location
# 2            2             Institutions
# 3            3         Credit3Container
# 4            4              VerifyPhone
# 5            5         BankVerification
# 6            6        VerifyDateOfBirth
# 7            7              ProfilePage
# 8            8            VerifyCountry
# 9            9                    Cycle
# 10          10                 idscreen
# 11          11         Credit3Dashboard
# 12          12                    Loan3
# 13          13              CC1Category
# 14          14                   Splash
# 15          15                     Loan
# 16          16                      CC1
# 17          17         RewardsContainer
# 18          18                  Credit3
# 19          19                  Credit1
# 20          20              EditProfile
# 21          21                  Credit2
# ...
